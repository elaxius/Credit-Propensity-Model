# %%
import pandas as pd
import numpy as np
from optbinning import OptimalBinning
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# read data
df_demog = pd.read_excel('Data/DataScientist_CaseStudy_Dataset.xlsx', sheet_name='Soc_Dem')
df_bal = pd.read_excel('Data/DataScientist_CaseStudy_Dataset.xlsx', sheet_name='Products_ActBalance')
df_in_out = pd.read_excel('Data/DataScientist_CaseStudy_Dataset.xlsx', sheet_name='Inflow_Outflow')
df_target = pd.read_excel('Data/DataScientist_CaseStudy_Dataset.xlsx', sheet_name='Sales_Revenues')
df_desc = pd.read_excel('Data/DataScientist_CaseStudy_Dataset.xlsx', sheet_name='Description')

# %%
#Generate train test data
df_master = (df_demog
             .merge(df_in_out, on='Client')
             .merge(df_bal, on='Client'))
df_master_label = df_master.merge(df_target, on='Client')
df_master_label
# Out:
#      Client Sex  Age  Tenure   VolumeCred  VolumeCred_CA  TransactionsCred  \
# 0      1217   M   38     165     0.002143       0.002143                 1
# 1       850   F   49      44  1392.402857    1392.402857                 3
# 2      1473   M   54      34  1787.127500     939.128929                14
# 3      1038   M   29     106     0.006071       0.006071                 1
# 4       225   M   14     187     0.007500       0.007500                 1
# ..      ...  ..  ...     ...          ...            ...               ...
# 946     621   F   37     152     7.397857       0.002500                 3
# 947    1276   M   28     145   610.893214     514.313214                 4
# 948     384   M   23     160    87.500357      87.500357                 2
# 949     977   M   46      59    71.428571      71.428571                 1
# 950     629   F   61     173  1064.190000    1064.190000                 3
#
#      TransactionsCred_CA    VolumeDeb  VolumeDeb_CA  ...     ActBal_MF  \
# 0                      1   714.285714    714.285714  ...           NaN
# 1                      3  1226.345357   1226.345357  ...           NaN
# 2                      5  3875.137857   3794.580714  ...           NaN
# 3                      1     0.000000      0.000000  ...           NaN
# 4                      1   130.521429    130.521429  ...           NaN
# ..                   ...          ...           ...  ...           ...
# 946                    1     0.288929      0.000000  ...           NaN
# 947                    3   165.928571    155.107143  ...           NaN
# 948                    2    88.443929     88.443929  ...           NaN
# 949                    1    76.103571     76.103571  ...           NaN
# 950                    3   817.462143    817.462143  ...  34387.583571
#
#      ActBal_OVD  ActBal_CC    ActBal_CL  Sale_MF  Sale_CC  Sale_CL  \
# 0           NaN        NaN          NaN        0        0        0
# 1           NaN        NaN          NaN        0        1        0
# 2           NaN     653.91  1132.590357        1        0        0
# 3           NaN        NaN          NaN        0        0        0
# 4      618.3975        NaN          NaN        0        0        1
# ..          ...        ...          ...      ...      ...      ...
# 946         NaN        NaN          NaN        0        0        0
# 947         NaN        NaN  1764.589286        0        0        0
# 948         NaN        NaN          NaN        0        1        1
# 949         NaN        NaN          NaN        1        0        0
# 950         NaN        NaN          NaN        0        1        0
#
#      Revenue_MF  Revenue_CC  Revenue_CL
# 0      0.000000    0.000000    0.000000
# 1      0.000000    0.893929    0.000000
# 2      4.929643    0.000000    0.000000
# 3      0.000000    0.000000    0.000000
# 4      0.000000    0.000000    8.130714
# ..          ...         ...         ...
# 946    0.000000    0.000000    0.000000
# 947    0.000000    0.000000    0.000000
# 948    0.000000    6.107143   12.506071
# 949    1.429643    0.000000    0.000000
# 950    0.000000   49.080714    0.000000
#
# [951 rows x 36 columns]

# %%
binning = OptimalBinning(name="Age", dtype="numerical")
binning.fit(df_master_label["Age"], df_master_label["Sale_CC"])

binning_table = binning.binning_table.build()
display(binning_table)
# Out:
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/joeytian/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#                    Bin  Count  Count (%)  Non-event  Event  Event rate  \
# 0        (-inf, 16.50)     55   0.057834         47      8    0.145455
# 1       [16.50, 29.50)    198   0.208202        154     44    0.222222
# 2       [29.50, 51.50)    391   0.411146        293     98    0.250639
# 3       [51.50, 56.50)     53   0.055731         37     16    0.301887
# 4       [56.50, 61.50)     61   0.064143         39     22    0.360656
# 5       [61.50, 72.50)    138   0.145110        102     36    0.260870
# 6         [72.50, inf)     55   0.057834         42     13    0.236364
# 7              Special      0   0.000000          0      0    0.000000
# 8              Missing      0   0.000000          0      0    0.000000
# Totals                    951   1.000000        714    237    0.249211
#
#              WoE        IV        JS
# 0       0.667883  0.021420  0.002629
# 1        0.14994  0.004503  0.000562
# 2      -0.007618  0.000024  0.000003
# 3      -0.264494  0.004150  0.000517
# 4      -0.530304  0.020260  0.002503
# 5      -0.061369  0.000555  0.000069
# 6       0.069897  0.000278  0.000035
# 7            0.0  0.000000  0.000000
# 8            0.0  0.000000  0.000000
# Totals            0.051189  0.006319

# %%
pip install -U scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /Users/joeytian/Library/Python/3.9/lib/python/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/joeytian/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/joeytian/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/joeytian/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/joeytian/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.6.0)
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
